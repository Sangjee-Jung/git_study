# %% [markdown]
# # Summary

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('./가동률/17.1.xlsx', sheet_name = '02')
df2 = pd.read_excel('./가동률/17.1.xlsx', sheet_name = '03')

# %%
display(df1)
display(df2)
# Out:
#    2017년 01월 02일 일일생산현황(03일(화) 09시 현재) Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                  NaN        NaN        NaN         NaN
# 1                                  NaN        NaN        NaN         NaN
# 2                                 호\n기         구분        고객사        품  명
# 3                                  NaN        NaN        NaN         NaN
# 4                                    1         발주      HICON  LEAD GUIDE
# ..                                 ...        ...        ...         ...
# 80                       설비 점검 내역(02일)        NaN        NaN         NaN
# 81                                  순위        NaN      호   기         NaN
# 82                                   1        NaN        NaN         NaN
# 83                                   2        NaN        NaN         NaN
# 84                                   3        NaN        NaN         NaN
#
#          Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# ...

# %%
df = pd.concat([df1, df2])
df
# Out:
#    2017년 01월 02일 일일생산현황(03일(화) 09시 현재) Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                                  NaN        NaN        NaN         NaN
# 1                                  NaN        NaN        NaN         NaN
# 2                                 호\n기         구분        고객사        품  명
# 3                                  NaN        NaN        NaN         NaN
# 4                                    1         발주      HICON  LEAD GUIDE
# ..                                 ...        ...        ...         ...
# 81                                 NaN        NaN        NaN         NaN
# 82                                 NaN        NaN      호   기         NaN
# 83                                 NaN        NaN        NaN         NaN
# 84                                 NaN        NaN        NaN         NaN
# 85                                 NaN        NaN        NaN         NaN
#
#          Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# ...
